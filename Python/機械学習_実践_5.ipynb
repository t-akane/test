# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
fig = plt.figure(figsize=(3,3))
ax = fig.add_subplot(111)
c1 = mpatches.Arc(xy=(0.4,0.5), width=0.4, height=0.4, angle=30,
                  theta1=0, theta2=230, linewidth=10, color="lightblue")
c2 = mpatches.Arc(xy=(0.6,0.5), width=0.4, height=0.4, angle=30,
                  theta1=0, theta2=230, linewidth=10, color="pink")
ax.add_patch(c1)
ax.add_patch(c2)
plt.show()

# %%
#サークルポリゴン　正多角形
fig = plt.figure(figsize=(3,3))
ax = fig.add_subplot(111)
cp1 = mpatches.CirclePolygon(xy = (0.5,0.5), radius=0.4,
                             resolution=6, color="lightblue") #resolutionは辺の数
cp2 = mpatches.CirclePolygon(xy = (0.5,0.5), radius=0.2,
                             resolution=8, color="white")
ax.add_patch(cp1)
ax.add_patch(cp2)
plt.show()

# %%
#エリプス　楕円形
fig = plt.figure(figsize=(5,5)) #横、縦の順番　キャンバスの大きさ
ax = fig.add_subplot(111)
e1 = mpatches.Ellipse(xy=(0.5,0.5), width=0.8, height=0.5,
                      angle=30, color="lightblue")
e2 = mpatches.Ellipse(xy=(0.5,0.5), width=0.5, height=0.2,
                      angle=30, color="lightgray")
ax.add_patch(e1)
ax.add_patch(e2)
plt.show()

# %%
#Wedge 扇型
fig = plt.figure(figsize=(3,3))
ax = fig.add_subplot(111)
w1 = mpatches.Wedge(center=(0.3,0.55), r=0.25,
                    theta1=30, theta2=-30, color="pink")
w2 = mpatches.Wedge(center=(0.7,0.4), r=0.25,
                    theta1=210, theta2=150, color="lightblue")
ax.add_patch(w1)
ax.add_patch(w2)
plt.show()

# %%
#レクタングル　長方形
fig = plt.figure(figsize=(3,3))
ax = fig.add_subplot(111)
r1 = mpatches.Rectangle(xy=(0.1,0.4), width=0.5, height=0.5,
                        angle=0, color="lightblue")
r2 = mpatches.Rectangle(xy=(0.4,0.1), width=0.5, height=0.5,
                        angle=0, color="pink")
ax.add_patch(r1)
ax.add_patch(r2)
plt.show()

# %%
# ポリゴン　多角形
fig = plt.figure(figsize=(3,3))
ax = fig.add_subplot(111)
p1 = mpatches.Polygon(xy=[(0, 0.2), (0.3, 0.8), (0.6,0.2)],
                       facecolor="lightblue")
p2 = mpatches.Polygon(xy=[(0.4, 0.8),(0.7,0.2),(1.0,0.8)],
                       facecolor="pink")
ax.add_patch(p1)
ax.add_patch(p2)
plt.show()

# %% [markdown]
# # フィギュアオブジェクトとサブプロットの調整

# %%
import matplotlib.pyplot as plt
fig = plt.figure(
                 figsize=(3,3),
                 dpi = 100, #解像度
                 facecolor="gray", #塗りつぶし色
                 edgecolor = "k", #枠線の色
                 linewidth=10,
                 frameon=True,#枠線を表示する
                 tight_layout=False)
ax1 = fig.add_subplot(111)
plt.show()

# %%
fig = plt.figure(figsize=(3,3))
#サブプロットの書式設定
ax = fig.add_subplot(111,
                     facecolor="lightblue",　#描画エリアの背景色
                     xlim=[0,15],
                     ylim=[1,10000],
                     yscale="log")
ax.plot([1,5,10], [10,100,1000])
plt.show()
# Out:
#   File "<ipython-input-67-b4d0497cca4f>", line 4
#     facecolor="lightblue",　#描画エリアの背景色
#                           ^
# SyntaxError: invalid character in identifier

# %%
fig = plt.figure(figsize=(3,3))

ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
plt.show()

# %%
fig = plt.figure(figsize=(3,3))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
#サブプロット間余白調整
fig.subplots_adjust(wspace=0.5, hspace=0.5) #Wがワイズで、hがハイト
plt.show()

# %%
fig = plt.figure(figsize=(3,3))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
#サブプロット周りのスペース調整
fig.subplots_adjust(left=0.2, right=0.8, bottom=0.2, top=0.8)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.arange(0,6,0.1)
y = np.sin(x)
z = np.cos(x)
fig = plt.figure()
ax = fig.add_subplot(111)
#描画
ax.scatter(x,y,label="sin", color="lightblue", edgecolor="blue")
ax.scatter(x,z,label="cos",color="lightblue", edgecolor="blue", alpha=0.3)
ax.legend(framealpha=1, loc="lower right")
plt.show()

# %%
fig = plt.figure(figsize=(6,3))
ax = fig.add_subplot(111, xlim=(0,14))
x = np.arange(0,3,0.1)
y = np.cos(x)
ax.scatter(x,y,label="color string",color="b")
ax.scatter(x+0.5,y,label="RGBA tuple", color=(0.1,0,0.5,1))
ax.scatter(x+1.0,y,label="RGBA 16", color="#330099")
ax.scatter(x+1.5,y,label="Gray scale", color="0.3")
ax.scatter(x+2.0,y,label="HTML color", color="DarkOliveGreen")
ax.scatter(x+2.5,y,label="X11/CSS", color="DarkSeaGreen")
ax.scatter(x+3.0,y,label="Regular expression", color="C8")
ax.scatter(x+3.5,y,label="Tableau", color="tab:gray")
ax.legend()
plt.show()

# %%
#カラーマップの基本的な使用方法
import matplotlib.cm as cm
fig = plt.figure()
ax = fig.add_subplot(111)
x = np.arange(20)
y = np.arange(20)
ax.scatter(x,y+5,color=cm.spring(0.5),label="spring(0.5)")
ax.scatter(x,y,color=cm.get_cmap("winter")(0.5),label="winter(0.5)")
ax.legend()
plt.show()

# %%
#cmapカラーマップに指定すると、要素の色を段階的に変化させることができる
#cに与えたxの値に応じて、散布図の要素の色を自動で割り当てている。
fig = plt.figure(figsize=(4.5,2))
ax = fig.add_subplot(111)
n = 20
x = np.arange(n)
y = np.ones(n)
ax.scatter(x,y,c=x,cmap=cm.Set1)
plt.show()

# %%
fig = plt.figure(figsize=(4.5,2))
ax = fig.add_subplot(111)
n = 20
x = np.arange(n)
y = np.ones(n)
for i in range(n):
    color = cm.Set1(i / n*0.5)
    ax.scatter(x[ i ], y[ i ], c=color)
plt.show()

# %% [markdown]
# ## 線の書式設定

# %%
#線の色と太さの指定
import matplotlib.pyplot as plt
import numpy as np
plt.style.use("ggplot")
x = np.array([0,1])
y = [0,1]
fig = plt.figure(figsize=(9,3))
ax  = fig.add_subplot(111,xlim=(-0.2,4))
#線の太さと透明度を設定
ax.plot(x,y,linewidth=1, color="r",label="linewidth=1(alpha=1.0)")
ax.plot(x+0.1,y,linewidth=1,color="y",alpha=0.5,
        label="linewidth=1(alpha=0.5)")

ax.plot(x+1.1,y,linewidth=10, color="b",label="linewidth=10(alpha=1.0)")
ax.plot(x+1.3,y,linewidth=10,color="g",alpha=0.5,
        label="linewidth=10(alpha=0.5)")
ax.legend()
plt.show()

# %%
x = [0.1,1]
y = np.array([0,0])
fig = plt.figure(figsize=(6,3))
ax = fig.add_subplot(111,xlim=(0,1.7),ylim=(-0.2,1.2))
#線の先端形状を設定
ax.plot(x,y+1,linewidth=12,solid_capstyle="butt",label="butt")
ax.plot(x,y+0.5,linewidth=12,solid_capstyle="round",label="round")
ax.plot(x,y,linewidth=12,solid_capstyle="projecting",label="projecting")
ax.legend(loc=1)
plt.show()

# %%
x = np.array([0,1,2,3])
y = [0,1.0,0.2,1.2]
fig = plt.figure(figsize=(6,3))
ax = fig.add_subplot(111,xlim=(0,4.5))
#線の結合店の形状を設定
ax.plot(x,y,linewidth=10,solid_joinstyle="miter",label="miter")
ax.plot(x+0.5,y,linewidth=10,solid_joinstyle="round",label="round")
ax.plot(x+1.0,y,linewidth=10,solid_joinstyle="bevel",label="bevel")
ax.legend()
plt.show()

# %%
x = np.array([0,1])
y = np.array([1.9,1.9])
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111,xlim=(-0.1,1.7),ylim=(0,2))
#線の種類
ax.plot(x,y,linewidth=5,color="b",linestyle="solid",label="solid")
ax.plot(x,y-0.1,linewidth=5,color="b",alpha=0.5,linestyle="-",label="-")

ax.plot(x,y-0.4,linewidth=5,color="b",linestyle="dashed",label="dashed")
ax.plot(x,y-0.6,linewidth=5,color="b",alpha=0.5,linestyle="--",label="--")
ax.legend()
plt.show()

# %%
x = [0.1,1]
y = np.array([0,0])
fig = plt.figure(figsize=(6,3))
ax = fig.add_subplot(111,xlim=(0,1.7),ylim=(-0.2,1.2))
ax.plot(x,y+1,linewidth=12,linestyle="-.",dash_capstyle="butt",label="butt")
ax.plot(x,y+0.5,linewidth=12,linestyle="-.",dash_capstyle="round",label="round")
ax.plot(x,y,linewidth=12,linestyle="-.",dash_capstyle="projecting",label="projecting")
ax.legend()
plt.show()

# %%
x = np.array([0,1,2,3])
y = [0,1.0,0.2,1.2]
fig = plt.figure(figsize=(6,3))
ax = fig.add_subplot(111,xlim=(0,4.5))
#は線の結合形状を変える
ax.plot(x,y,linewidth=10,linestyle=(0,(3,0.5)),
        dash_joinstyle="miter",label="miter")
ax.plot(x+0.5,y,linewidth=10,linestyle=(0,(3,0.5)),
        dash_joinstyle="round",label="round")
ax.plot(x+1.0,y,linewidth=10,linestyle=(0,(3,0.5)),
        dash_joinstyle="bevel",label="bevel")
ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(3,3))
ax = fig.add_subplot(111)
ax.text(2,4,"Text",size=40)
ax.set_xticks([ i * 2 for i in range(6)])
ax.set_yticks([ i * 2 for i in range(6)])
ax.grid(linestyle="-")
plt.show()

# %%
fig = plt.figure(figsize=(3,3))
ax = fig.add_subplot(111)
ax.text(0.2,0.6,"text",alpha=0.5,color="Red",size=40)
fps={
    "family":"fantasy",
    "style":"italic",
    "weight":"heavy",
    "size":40,
"color":"Green"
}
ax.text(0.2,0.2,"text",alpha=0.5,color="Red",fontdict=fps)
ticks = [0.2 * i for i in range(6)]
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.grid(linestyle="-")
plt.show()

# %%
fig = plt.figure(figsize=(3,3))
ax = fig.add_subplot(111)
boxprops = {
    "facecolor":"pink",
    "edgecolor":"red",
    "alpha":0.5,
    "boxstyle":"Sawtooth",
    "linewidth":2
}
#テキストボックス
ax.text(0.07,0.5,"textbox\nfrom dictionaly\nSetteing",
        bbox=boxprops,size=18)
ax.text(0.07,0.2,"backgroundcolor",bbox={"alpha":0.2},
        backgroundcolor="Blue",size=16)
ticks = [0.2 * i for i in range(6)]
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.grid(linestyle="-")
plt.show()

# %%
#テキストボックスの水平方向の配置を設定
fig = plt.figure(figsize=(3,3))
ax = fig.add_subplot(111)
x,y = [0.5,0.5],[0,4]
ax.plot(x,y)
#テキストボックスの描画
ax.text(0.5,3,"left",horizontalalignment="left",size=20)
ax.text(0.5,2,"center",horizontalalignment="center",size=20)
ax.text(0.5,1,"right",horizontalalignment="right",size=20)
ax.set_yticks([i for i in range(5)])
ax.set_xticks([0.5 * i for i in range(3)])
plt.show()

# %%
fig = plt.figure(figsize=(8,3))
ax = fig.add_subplot(111)

x,y = [0, 9], [0.5, 0.5]
ax.plot(x,y)

ax.text(0,0.5,"bottom",verticalalignment="bottom",size=20)
ax.text(2.5,0.5,"baseline", verticalalignment="baseline",size=20)
ax.text(5.5,0.5,"center",verticalalignment="center",size=20)
ax.text(8,0.5,"top",verticalalignment="top",size=20)
ax.set_xticks([i * 3 for i in range(4)])
ax.set_yticks([0.5 * i for i in range(3)])
plt.show()

# %%
#テキストボックスの文字列の水平方向の配置
fig = plt.figure(figsize=(4,7))
ax = fig.add_subplot(111,xlim=[0,5],ylim=[0,14])
ax.text(1,10,"Left\nalignment",multialignment="left",size=20)
ax.text(1,6,"Center\nalignment",multialignment="center",size=20)
ax.text(1,2,"Right\nalignment",multialignment="right",size=20)
ax.grid(linestyle="-")
plt.show()

# %%
fig = plt.figure(figsize=(3.5,5))
ax = fig.add_subplot(111,lim=[0,4], ylim=[0,7])
ax.te
